# %% [markdown]
# **1. Створення змінних**

# %%
name = 'Oleksandra'
age = 29
height = 1.64
is_student = False

# %%
print(name)
print(age)
print(height)
print(is_student)
# Out:
# Oleksandra
# 29
# 1.64
# False

# %% [markdown]
# **2. Арифметичні операції**

# %%
var1 = 15
var2 = 4

# %%
sum = var1 + var2
sub = var1 - var2
mul = var1 * var2
div = var1 / var2
int = var1 // var2
rem = var1 % var2
expon = var1 ** var2

# %%
print(sum)
print(sub)
print(mul)
print(div)
print(int)
print(rem)
expon
# Out:
# 19
# 11
# 60
# 3.75
# 3
# 3
# 50625

# %% [markdown]
# **3. Робота з рядками**

# %%
last_name = 'Hryhorus'

# %%
full_name = name + ' ' + last_name

# %%
full_name.upper()
# Out:
# 'OLEKSANDRA HRYHORUS'

# %%
full_name.lower()
# Out:
# 'oleksandra hryhorus'

# %%
len(full_name)
# Out:
# 19

# %%
f'"Мене звати {name}, мені {age} років".'
# Out:
# '"Мене звати Oleksandra, мені 29 років".'
